# %% [markdown]
# # NAME: RAJA HAIDER ALI
# # CMS ID: 346900
# # CLASS: BESE 11-A

# %% [markdown]
# Most machine learning workflows involve working with data, creating models, optimizing model parameters, and saving the trained models. This tutorial introduces you to a complete ML workflow implemented in PyTorch covering all these steps.

# %% [markdown]
# #Task 1

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
import random
import numpy as np

# %% [markdown]
# Check if GPU is available.

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print ('<== CUDA availability : ==>', use_cuda)
# Out:
# <== CUDA availability : ==> True

# %% [markdown]
# Set seed for reproducability.

# %%
def set_seeds(seed):
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.determinictic = True
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    random.seed(seed)
set_seeds(42)

# %% [markdown]
# PyTorch offers domain-specific libraries such as TorchText, TorchVision, and TorchAudio, all of which include datasets. For this lab, we will be using a TorchVision dataset. Load one of the prebuilt datasets from pytorch repository. Currently, we are not using any transform (manipulation) on input data. We are just converting each image to tensor.

# %%
training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.MNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 209215442.90it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 112999714.39it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 77139797.41it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 21143761.12it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %% [markdown]
# Visualise some of the input images.

# %%
labels_map = {
    0: "zero",
    1: "one",
    2: "two",
    3: "three",
    4: "four",
    5: "five",
    6: "six",
    7: "seven",
    8: "eight",
    9: "nine",
}
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()  # randomly pick indices from the training data
    img, label = training_data[sample_idx]                            # Read the images using their indices.
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %% [markdown]
# Check the size and shape of training and validation data.

# %%
print ('Shape of Training Data', np.shape(training_data))
print ('Shape of Test Data', np.shape(test_data))
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:2009: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   result = asarray(a).shape
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:2009: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape
# Shape of Training Data (60000, 2)
# Shape of Test Data (10000, 2)

# %% [markdown]
# The shape of the training set is (6000,2). This means that we have 6000 thousand samples with 2 entities. The first entity is the image and the second entity is its label. Forexample:
#
# **training_data[0][0]** is the first image of training set
#
# **training_data[0][1]** is the label of the first image in the training set

# %% [markdown]
# Now pass the Dataset as an argument to DataLoader. This wraps an iterable over our dataset, and supports automatic batching, sampling, shuffling and multiprocess data loading. Here we define a batch size of 64, i.e. each element in the dataloader iterable will return a batch of 64 features and labels.

# %%
batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64

# %% [markdown]
# To define a neural network in PyTorch, we create a class that inherits from nn.Module. We define the layers of the network in the __init__ function and specify how data will pass through the network in the forward function. To accelerate operations in the neural network, we move it to the GPU if available.

# %%
# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)
# Out:
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# # Q1 You may change the width of each layer from 128 to 256 and 512 and observe the difference in network performance.
#
# # Try adding and removing layers. Keeping all other setup the same, how does the network behave with the change in depth (number of layers) and width (size of each layer)?

# %% [markdown]
# Now define the loss function and set up optimiser.

# %%
loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=1e-3 )

# %% [markdown]
# # Q2: Try changing the learning rate from 1e-3 to 1e-4. What do you observe?
#
# # Try the Adam optimizer instead of SGD. How the learning process changes?

# %% [markdown]
# Define train function.

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    running_loss = 0                            # accumuate loss of each input sample
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)       # assign input samples to the available device (CPU or GPU) for computation.

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()                   # set the gradients to zero to avoid gradient accumuation. Gradient Accumulation is useful in some cases, like in training RNN.
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            #print(f"training loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

    return running_loss/len(dataloader)

# %% [markdown]
# Define evaluation function.

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():         # No gradients need to be calculated for evaluation. Just the forward pass.
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size               # Normalise correctly classified count.
    print(f"test loss: \nAccuracy: {(100*correct):>0.1f}%, avg loss: {test_loss:>8f} \n")

    return test_loss

# %% [markdown]
# Initiate Training Process

# %%
epochs = 5
train_losses = []
test_losses = []

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    train_loss = train(train_dataloader, model, loss_fn, optimizer)
    train_losses.append(train_loss)

    test_loss = test(test_dataloader, model, loss_fn)
    test_losses.append(test_loss)

print("Done!")

# Plot training and validation losses.
plt.figure(figsize=(10,5))
plt.title("Training and Validation Loss")
plt.plot(test_losses,label="validation")
plt.plot(train_losses,label="training")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Epoch 1
# -------------------------------
# test loss:
# Accuracy: 23.4%, avg loss: 2.277006
#
# Epoch 2
# -------------------------------
# test loss:
# Accuracy: 43.4%, avg loss: 2.238353
#
# Epoch 3
# -------------------------------
# test loss:
# Accuracy: 60.9%, avg loss: 2.175058
#
# Epoch 4
# -------------------------------
# test loss:
# Accuracy: 66.1%, avg loss: 2.066408
#
# Epoch 5
# -------------------------------
# test loss:
# Accuracy: 69.9%, avg loss: 1.889621
#
# Done!

# %% [markdown]
# # Combination: 01

# %%
set_seeds(42)

training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.MNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

labels_map = {
    0: "zero",
    1: "one",
    2: "two",
    3: "three",
    4: "four",
    5: "five",
    6: "six",
    7: "seven",
    8: "eight",
    9: "nine",
}
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()  # randomly pick indices from the training data
    img, label = training_data[sample_idx]                            # Read the images using their indices.
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

print ('Shape of Training Data', np.shape(training_data))
print ('Shape of Test Data', np.shape(test_data))

batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)

loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=1e-3 )

epochs = 10
train_losses = []
test_losses = []

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    train_loss = train(train_dataloader, model, loss_fn, optimizer)
    train_losses.append(train_loss)

    test_loss = test(test_dataloader, model, loss_fn)
    test_losses.append(test_loss)

print("Done!")

# Plot training and validation losses.
plt.figure(figsize=(10,5))
plt.title("Training and Validation Loss")
plt.plot(test_losses,label="validation")
plt.plot(train_losses,label="training")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Shape of Training Data (60000, 2)
# Shape of Test Data (10000, 2)
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# Epoch 1
# -------------------------------
# test loss:
# Accuracy: 23.4%, avg loss: 2.277006
#
# Epoch 2
# -------------------------------
# test loss:
# Accuracy: 43.4%, avg loss: 2.238353
#
# Epoch 3
# -------------------------------
# test loss:
# Accuracy: 60.9%, avg loss: 2.175058
#
# Epoch 4
# -------------------------------
# test loss:
# Accuracy: 66.1%, avg loss: 2.066408
#
# Epoch 5
# -------------------------------
# test loss:
# Accuracy: 69.9%, avg loss: 1.889621
#
# Epoch 6
# -------------------------------
# test loss:
# Accuracy: 73.1%, avg loss: 1.633308
#
# Epoch 7
# -------------------------------
# test loss:
# Accuracy: 74.8%, avg loss: 1.331525
#
# Epoch 8
# -------------------------------
# test loss:
# Accuracy: 77.3%, avg loss: 1.069518
#
# Epoch 9
# -------------------------------
# test loss:
# Accuracy: 79.8%, avg loss: 0.886347
#
# Epoch 10
# -------------------------------
# test loss:
# Accuracy: 81.5%, avg loss: 0.764056
#
# Done!

# %% [markdown]
# # Combination: 02

# %%
set_seeds(42)

training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.MNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

labels_map = {
    0: "zero",
    1: "one",
    2: "two",
    3: "three",
    4: "four",
    5: "five",
    6: "six",
    7: "seven",
    8: "eight",
    9: "nine",
}
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()  # randomly pick indices from the training data
    img, label = training_data[sample_idx]                            # Read the images using their indices.
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

print ('Shape of Training Data', np.shape(training_data))
print ('Shape of Test Data', np.shape(test_data))

batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)

loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=1e-3 )

epochs = 20
train_losses = []
test_losses = []

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    train_loss = train(train_dataloader, model, loss_fn, optimizer)
    train_losses.append(train_loss)

    test_loss = test(test_dataloader, model, loss_fn)
    test_losses.append(test_loss)

print("Done!")

# Plot training and validation losses.
plt.figure(figsize=(10,5))
plt.title("Training and Validation Loss")
plt.plot(test_losses,label="validation")
plt.plot(train_losses,label="training")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Shape of Training Data (60000, 2)
# Shape of Test Data (10000, 2)
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# Epoch 1
# -------------------------------
# test loss:
# Accuracy: 23.4%, avg loss: 2.277006
#
# Epoch 2
# -------------------------------
# test loss:
# Accuracy: 43.4%, avg loss: 2.238353
#
# Epoch 3
# -------------------------------
# test loss:
# Accuracy: 60.9%, avg loss: 2.175058
#
# Epoch 4
# -------------------------------
# test loss:
# Accuracy:
#
# Epoch 9
# -------------------------------
# test loss:
# Accuracy: 96.7%, avg loss: 0.107520
#
# Epoch 10
# -------------------------------
# test loss:
# Accuracy: 97.0%, avg loss: 0.101085
#
# Epoch 11
# -------------------------------
# test loss:
# Accuracy: 97.2%, avg loss: 0.096014
#
# Epoch 12
# -------------------------------
# test loss:
# Accuracy: 97.3%, avg loss: 0.092092
#
# Epoch 13
# -------------------------------
# test loss:
# Accuracy: 97.4%, avg loss: 0.088896
#
# Epoch 14
# -------------------------------
# test loss:
# Accuracy: 97.4%, avg loss: 0.086293
#
# Epoch 15
# -------------------------------
# test loss:
# Accuracy: 97.5%, avg loss: 0.084121
#
# Epoch 16
# -------------------------------
# test loss:
# Accuracy: 97.5%, avg loss: 0.082390
#
# Epoch 17
# -------------------------------
# test loss:
# Accuracy: 97.5%, avg loss: 0.081110
#
# Epoch 18
# -------------------------------
# test loss:
# Accuracy: 97.5%, avg loss: 0.079976
#
# Epoch 19
# -------------------------------
# test loss:
# Accuracy: 97.6%, avg loss: 0.079158
#
# Epoch 20
# -------------------------------
# test loss:
# Accuracy: 97.5%, avg loss: 0.078639
#
# Done!

# %% [markdown]
# # Q3: Try 5, 10 and 50 epoch and record values for average validation loss and accuracy

# %% [markdown]
# # Q4: What activation function is generally used for multiclass classification? Why didn't we use an activation function at the end of our neural network that we have defined?

# %% [markdown]
# # Combination 10 has the highest accuracy and the lowest validation loss. Run the code cell of the combination 10 and then run the cell below to save the model and get the inference.

# %%
torch.save(model.state_dict(), "model.pth")
print("Saved PyTorch Model State to model.pth")
# Out:
# Saved PyTorch Model State to model.pth

# %% [markdown]
# Perform Inferrence

# %%
classes = [
    "zero",
    "one",
    "two",
    "three",
    "four",
    "five",
    "six",
    "seven",
    "eight",
    "nine",
]
#classes = np.array(test_data.class_to_idx.values())
#testimg = random.
model.eval()
sample_number = 300 # Keep 0 <= sample_number < 10,000
x, y = test_data[sample_number][0], test_data[sample_number][1]
model.to("cpu")
with torch.no_grad():
    pred = model(x)
    predicted, actual = classes[pred[0].argmax(0)], classes[y]
    print(f'Predicted: "{predicted}", Actual: "{actual}"')

img, label = test_data[sample_number]                            # Read the images using their indices.
    #figure.add_subplot(rows, cols, i)
plt.figure()
plt.title("Predcited: "+ predicted + "     Actual: " + labels_map[label])
plt.axis("off")
plt.imshow(img.squeeze(), cmap="gray")
# Out:
# Predicted: "four", Actual: "four"

# %% [markdown]
# #Task 2

# %% [markdown]
# #Repeat all of above steps for Fashion MNIST dataset, apply question 1, 2 and 3 and report the accuracies.

# %% [markdown]
# # Combination: 01

# %%
set_seeds(42)

training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

labels_map = {
    0: "T-shirt/top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot",
}

figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()  # randomly pick indices from the training data
    img, label = training_data[sample_idx]                            # Read the images using their indices.
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

print ('Shape of Training Data', np.shape(training_data))
print ('Shape of Test Data', np.shape(test_data))

batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)

loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3 )

epochs = 10
train_losses = []
test_losses = []

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    train_loss = train(train_dataloader, model, loss_fn, optimizer)
    train_losses.append(train_loss)

    test_loss = test(test_dataloader, model, loss_fn)
    test_losses.append(test_loss)

print("Done!")

# Plot training and validation losses.
plt.figure(figsize=(10,5))
plt.title("Training and Validation Loss")
plt.plot(test_losses,label="validation")
plt.plot(train_losses,label="training")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:2009: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   result = asarray(a).shape
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:2009: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape
# Shape of Training Data (60000, 2)
# Shape of Test Data (10000, 2)
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# Epoch 1
# -------------------------------
# test loss:
# Accuracy: 83.8%, avg loss: 0.451477
#
# Epoch 2
# -------------------------------
# test loss:
# Accuracy: 85.3%, avg loss: 0.401167
#
# Epoch 3
# -------------------------------
# test loss:
# Accuracy: 86.2%, avg loss: 0.374955
#
# Epoch 4
# -------------------------------
# test loss:
# Accuracy: 86.8%, avg loss: 0.360260
#
# Epoch 5
# -------------------------------
# test loss:
# Accuracy: 87.2%, avg loss: 0.353808
#
# Epoch 6
# -------------------------------
# test loss:
# Accuracy: 87.0%, avg loss: 0.356500
#
# Epoch 7
# -------------------------------
# test loss:
# Accuracy: 87.3%, avg loss: 0.353946
#
# Epoch 8
# -------------------------------
# test loss:
# Accuracy: 87.8%, avg loss: 0.348430
#
# Epoch 9
# -------------------------------
# test loss:
# Accuracy: 87.7%, avg loss: 0.350122
#
# Epoch 10
# -------------------------------
# test loss:
# Accuracy: 87.5%, avg loss: 0.351616
#
# Done!

# %% [markdown]
# # Combination: 02

# %%
set_seeds(42)

training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

labels_map = {
    0: "T-shirt/top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot",
}

figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()  # randomly pick indices from the training data
    img, label = training_data[sample_idx]                            # Read the images using their indices.
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

print ('Shape of Training Data', np.shape(training_data))
print ('Shape of Test Data', np.shape(test_data))

batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)

loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3 )

epochs = 20
train_losses = []
test_losses = []

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    train_loss = train(train_dataloader, model, loss_fn, optimizer)
    train_losses.append(train_loss)

    test_loss = test(test_dataloader, model, loss_fn)
    test_losses.append(test_loss)

print("Done!")

# Plot training and validation losses.
plt.figure(figsize=(10,5))
plt.title("Training and Validation Loss")
plt.plot(test_losses,label="validation")
plt.plot(train_losses,label="training")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Shape of Training Data (60000, 2)
# Shape of Test Data (10000, 2)
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# Epoch 1
# -------------------------------
# test loss:
# Accuracy: 83.8%, avg loss: 0.451477
#
# Epoch 2
# -------------------------------
# test loss:
# Accuracy: 85.3%, avg loss: 0.401167
#
# Epoch 3
# -------------------------------
# test loss:
# Accuracy: 86.2%, avg loss: 0.374955
#
# Epoch 4
# -------------------------------
# test loss:
# Accuracy: 86.8%, avg loss: 0.360260
#
# Epoch 5
# -------------------------------
# test loss:
# Accuracy: 87.2%, avg loss: 0.353808
#
# Epoch 6
# -------------------------------
# test loss:
# Accuracy: 87.0%, avg loss: 0.356500
#
# Epoch 7
# -------------------------------
# test loss:
# Accuracy: 87.3%, avg loss: 0.353946
#
# Epoch 8
# -------------------------------
# test loss:
# Accuracy: 87.8%, avg loss: 0.348430
#
# Epoch 9
# -------------------------------
# test loss:
# Accuracy: 87.7%, avg loss: 0.350122
#
# Epoch 10
# -------------------------------
# test loss:
# Accuracy: 87.5%, avg loss: 0.351616
#
# Epoch 11
# -------------------------------
# test loss:
# Accuracy: 87.9%, avg loss: 0.348746
#
# Epoch 12
# -------------------------------
# test loss:
# Accuracy: 87.7%, avg loss: 0.366248
#
# Epoch 13
# -------------------------------
# test loss:
# Accuracy: 87.7%, avg loss: 0.358014
#
# Epoch 14
# -------------------------------
# test loss:
# Accuracy: 87.8%, avg loss: 0.370307
#
# Epoch 15
# -------------------------------
# test loss:
# Accuracy: 87.8%, avg loss: 0.370590
#
# Epoch 16
# -------------------------------
# test loss:
# Accuracy: 87.7%, avg loss: 0.381681
#
# Epoch 17
# -------------------------------
# test loss:
# Accuracy: 87.7%, avg loss: 0.420823
#
# Epoch 18
# -------------------------------
# test loss:
# Accuracy: 87.8%, avg loss: 0.405381
#
# Epoch 19
# -------------------------------
# test loss:
# Accuracy: 87.3%, avg loss: 0.437507
#
# Epoch 20
# -------------------------------
# test loss:
# Accuracy: 87.5%, avg loss: 0.437884
#
# Done!

# %% [markdown]
# # Combination: 03

# %%
set_seeds(42)

training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

labels_map = {
    0: "T-shirt/top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot",
}

figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()  # randomly pick indices from the training data
    img, label = training_data[sample_idx]                            # Read the images using their indices.
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

print ('Shape of Training Data', np.shape(training_data))
print ('Shape of Test Data', np.shape(test_data))

batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)

loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=1e-4 )

epochs = 10
train_losses = []
test_losses = []

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    train_loss = train(train_dataloader, model, loss_fn, optimizer)
    train_losses.append(train_loss)

    test_loss = test(test_dataloader, model, loss_fn)
    test_losses.append(test_loss)

print("Done!")

# Plot training and validation losses.
plt.figure(figsize=(10,5))
plt.title("Training and Validation Loss")
plt.plot(test_losses,label="validation")
plt.plot(train_losses,label="training")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:2009: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   result = asarray(a).shape
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:2009: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape
# Shape of Training Data (60000, 2)
# Shape of Test Data (10000, 2)
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# Epoch 1
# -------------------------------
# test loss:
# Accuracy: 12.9%, avg loss: 2.293627
#
# Epoch 2
# -------------------------------
# test loss:
# Accuracy: 14.3%, avg loss: 2.286258
#
# Epoch 3
# -------------------------------
# test loss:
# Accuracy: 16.3%, avg loss: 2.279012
#
# Epoch 4
# -------------------------------
# test loss:
# Accuracy: 18.8%, avg loss: 2.271686
#
# Epoch 5
# -------------------------------
# test loss:
# Accuracy: 21.3%, avg loss: 2.264103
#
# Epoch 6
# -------------------------------
# test loss:
# Accuracy: 23.1%, avg loss: 2.256129
#
# Epoch 7
# -------------------------------
# test loss:
# Accuracy: 24.0%, avg loss: 2.247701
#
# Epoch 8
# -------------------------------
# test loss:
# Accuracy: 24.6%, avg loss: 2.238751
#
# Epoch 9
# -------------------------------
# test loss:
# Accuracy: 24.9%, avg loss: 2.229198
#
# Epoch 10
# -------------------------------
# test loss:
# Accuracy: 25.4%, avg loss: 2.218948
#
# Done!

# %% [markdown]
# # Combination: 04

# %%
set_seeds(42)

training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

labels_map = {
    0: "T-shirt/top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot",
}

figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()  # randomly pick indices from the training data
    img, label = training_data[sample_idx]                            # Read the images using their indices.
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

print ('Shape of Training Data', np.shape(training_data))
print ('Shape of Test Data', np.shape(test_data))

batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)

loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4 )

epochs = 10
train_losses = []
test_losses = []

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    train_loss = train(train_dataloader, model, loss_fn, optimizer)
    train_losses.append(train_loss)

    test_loss = test(test_dataloader, model, loss_fn)
    test_losses.append(test_loss)

print("Done!")

# Plot training and validation losses.
plt.figure(figsize=(10,5))
plt.title("Training and Validation Loss")
plt.plot(test_losses,label="validation")
plt.plot(train_losses,label="training")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Shape of Training Data (60000, 2)
# Shape of Test Data (10000, 2)
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# Epoch 1
# -------------------------------
# test loss:
# Accuracy: 79.5%, avg loss: 0.587501
#
# Epoch 2
# -------------------------------
# test loss:
# Accuracy: 82.2%, avg loss: 0.505463
#
# Epoch 3
# -------------------------------
# test loss:
# Accuracy: 83.4%, avg loss: 0.471935
#
# Epoch 4
# -------------------------------
# test loss:
# Accuracy: 84.2%, avg loss: 0.451260
#
# Epoch 5
# -------------------------------
# test loss:
# Accuracy: 84.5%, avg loss: 0.436470
#
# Epoch 6
# -------------------------------
# test loss:
# Accuracy: 84.9%, avg loss: 0.425078
#
# Epoch 7
# -------------------------------
# test loss:
# Accuracy: 85.2%, avg loss: 0.415774
#
# Epoch 8
# -------------------------------
# test loss:
# Accuracy: 85.4%, avg loss: 0.407913
#
# Epoch 9
# -------------------------------
# test loss:
# Accuracy: 85.6%, avg loss: 0.401230
#
# Epoch 10
# -------------------------------
# test loss:
# Accuracy: 85.9%, avg loss: 0.395294
#
# Done!

# %% [markdown]
# # Combination: 05

# %%
set_seeds(42)

training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

labels_map = {
    0: "T-shirt/top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot",
}

figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()  # randomly pick indices from the training data
    img, label = training_data[sample_idx]                            # Read the images using their indices.
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

print ('Shape of Training Data', np.shape(training_data))
print ('Shape of Test Data', np.shape(test_data))

batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)

loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3 )

epochs = 10
train_losses = []
test_losses = []

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    train_loss = train(train_dataloader, model, loss_fn, optimizer)
    train_losses.append(train_loss)

    test_loss = test(test_dataloader, model, loss_fn)
    test_losses.append(test_loss)

print("Done!")

# Plot training and validation losses.
plt.figure(figsize=(10,5))
plt.title("Training and Validation Loss")
plt.plot(test_losses,label="validation")
plt.plot(train_losses,label="training")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Shape of Training Data (60000, 2)
# Shape of Test Data (10000, 2)
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=10, bias=True)
#   )
# )
# Epoch 1
# -------------------------------
# test loss:
# Accuracy: 84.0%, avg loss: 0.443850
#
# Epoch 2
# -------------------------------
# test loss:
# Accuracy: 85.3%, avg loss: 0.400313
#
# Epoch 3
# -------------------------------
# test loss:
# Accuracy: 86.4%, avg loss: 0.366838
#
# Epoch 4
# -------------------------------
# test loss:
# Accuracy: 87.0%, avg loss: 0.356808
#
# Epoch 5
# -------------------------------
# test loss:
# Accuracy: 87.2%, avg loss: 0.351237
#
# Epoch 6
# -------------------------------
# test loss:
# Accuracy: 88.1%, avg loss: 0.336763
#
# Epoch 7
# -------------------------------
# test loss:
# Accuracy: 88.0%, avg loss: 0.342568
#
# Epoch 8
# -------------------------------
# test loss:
# Accuracy: 87.8%, avg loss: 0.358043
#
# Epoch 9
# -------------------------------
# test loss:
# Accuracy: 87.6%, avg loss: 0.361820
#
# Epoch 10
# -------------------------------
# test loss:
# Accuracy: 87.3%, avg loss: 0.375166
#
# Done!

# %% [markdown]
# # Combination: 06

# %%
set_seeds(42)

training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

labels_map = {
    0: "T-shirt/top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot",
}

figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()  # randomly pick indices from the training data
    img, label = training_data[sample_idx]                            # Read the images using their indices.
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

print ('Shape of Training Data', np.shape(training_data))
print ('Shape of Test Data', np.shape(test_data))

batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)

loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3 )

epochs = 20
train_losses = []
test_losses = []

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    train_loss = train(train_dataloader, model, loss_fn, optimizer)
    train_losses.append(train_loss)

    test_loss = test(test_dataloader, model, loss_fn)
    test_losses.append(test_loss)

print("Done!")

# Plot training and validation losses.
plt.figure(figsize=(10,5))
plt.title("Training and Validation Loss")
plt.plot(test_losses,label="validation")
plt.plot(train_losses,label="training")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Shape of Training Data (60000, 2)
# Shape of Test Data (10000, 2)
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=10, bias=True)
#   )
# )
# Epoch 1
# -------------------------------
# test loss:
# Accuracy: 84.0%, avg loss: 0.443850
#
# Epoch 2
# -------------------------------
# test loss:
# Accuracy: 85.3%, avg loss: 0.400313
#
# Epoch 3
# -------------------------------
# test loss:
# Accuracy: 86.4%, avg loss: 0.366838
#
# Epoch 4
# -------------------------------
# test loss:
# Accuracy: 87.0%, avg loss: 0.356808
#
# Epoch 5
# -------------------------------
# test loss:
# Accuracy: 87.2%, avg loss: 0.351237
#
# Epoch 6
# -------------------------------
# test loss:
# Accuracy: 88.1%, avg loss: 0.336763
#
# Epoch 7
# -------------------------------
# test loss:
# Accuracy: 88.0%, avg loss: 0.342568
#
# Epoch 8
# -------------------------------
# test loss:
# Accuracy: 87.8%, avg loss: 0.358043
#
# Epoch 9
# -------------------------------
# test loss:
# Accuracy: 87.6%, avg loss: 0.361820
#
# Epoch 10
# -------------------------------
# test loss:
# Accuracy: 87.3%, avg loss: 0.375166
#
# Epoch 11
# -------------------------------
# test loss:
# Accuracy: 87.4%, avg loss: 0.382558
#
# Epoch 12
# -------------------------------
# test loss:
# Accuracy: 88.0%, avg loss: 0.382538
#
# Epoch 13
# -------------------------------
# test loss:
# Accuracy: 88.4%, avg loss: 0.387656
#
# Epoch 14
# -------------------------------
# test loss:
# Accuracy: 87.8%, avg loss: 0.413577
#
# Epoch 15
# -------------------------------
# test loss:
# Accuracy: 88.0%, avg loss: 0.404842
#
# Epoch 16
# -------------------------------
# test loss:
# Accuracy: 88.3%, avg loss: 0.400918
#
# Epoch 17
# -------------------------------
# test loss:
# Accuracy: 88.4%, avg loss: 0.409588
#
# Epoch 18
# -------------------------------
# test loss:
# Accuracy: 88.9%, avg loss: 0.410175
#
# Epoch 19
# -------------------------------
# test loss:
# Accuracy: 88.8%, avg loss: 0.409952
#
# Epoch 20
# -------------------------------
# test loss:
# Accuracy: 88.1%, avg loss: 0.446886
#
# Done!

# %% [markdown]
# # Combination: 07

# %%
set_seeds(42)

training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

labels_map = {
    0: "T-shirt/top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot",
}

figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()  # randomly pick indices from the training data
    img, label = training_data[sample_idx]                            # Read the images using their indices.
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

print ('Shape of Training Data', np.shape(training_data))
print ('Shape of Test Data', np.shape(test_data))

batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)

loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=1e-4 )

epochs = 20
train_losses = []
test_losses = []

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    train_loss = train(train_dataloader, model, loss_fn, optimizer)
    train_losses.append(train_loss)

    test_loss = test(test_dataloader, model, loss_fn)
    test_losses.append(test_loss)

print("Done!")

# Plot training and validation losses.
plt.figure(figsize=(10,5))
plt.title("Training and Validation Loss")
plt.plot(test_losses,label="validation")
plt.plot(train_losses,label="training")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:2009: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   result = asarray(a).shape
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:2009: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape
# Shape of Training Data (60000, 2)
# Shape of Test Data (10000, 2)
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=10, bias=True)
#   )
# )
# Epoch 1
# -------------------------------
# test loss:
# Accuracy: 11.2%, avg loss: 2.295685
#
# Epoch 2
# -------------------------------
# test loss:
# Accuracy: 11.4%, avg loss: 2.285518
#
# Epoch 3
# -------------------------------
# test loss:
# Accuracy: 12.0%, avg loss: 2.275576
#
# Epoch 4
# -------------------------------
# test loss:
# Accuracy: 13.3%, avg loss: 2.265705
#
# Epoch 5
# -------------------------------
# test loss:
# Accuracy: 16.0%, avg loss: 2.255705
#
# Epoch 6
# -------------------------------
# test loss:
# Accuracy: 21.0%, avg loss: 2.245401
#
# Epoch 7
# -------------------------------
# test loss:
# Accuracy: 25.5%, avg loss: 2.234625
#
# Epoch 8
# -------------------------------
# test loss:
# Accuracy: 28.4%, avg loss: 2.223193
#
# Epoch 9
# -------------------------------
# test loss:
# Accuracy: 30.9%, avg loss: 2.210941
#
# Epoch 10
# -------------------------------
# test loss:
# Accuracy: 33.4%, avg loss: 2.197722
#
# Epoch 11
# -------------------------------
# test loss:
# Accuracy: 36.5%, avg loss: 2.183403
#
# Epoch 12
# -------------------------------
# test loss:
# Accuracy: 40.1%, avg loss: 2.167845
#
# Epoch 13
# -------------------------------
# test loss:
# Accuracy: 43.5%, avg loss: 2.150894
#
# Epoch 14
# -------------------------------
# test loss:
# Accuracy: 46.1%, avg loss: 2.132396
#
# Epoch 15
# -------------------------------
# test loss:
# Accuracy: 48.5%, avg loss: 2.112242
#
# Epoch 16
# -------------------------------
# test loss:
# Accuracy: 50.8%, avg loss: 2.090363
#
# Epoch 17
# -------------------------------
# test loss:
# Accuracy: 52.8%, avg loss: 2.066715
#
# Epoch 18
# -------------------------------
# test loss:
# Accuracy: 54.4%, avg loss: 2.041249
#
# Epoch 19
# -------------------------------
# test loss:
# Accuracy: 56.3%, avg loss: 2.013921
#
# Epoch 20
# -------------------------------
# test loss:
# Accuracy: 57.6%, avg loss: 1.984717
#
# Done!

# %% [markdown]
# # Combination: 08

# %%
set_seeds(42)

training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

labels_map = {
    0: "T-shirt/top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot",
}

figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()  # randomly pick indices from the training data
    img, label = training_data[sample_idx]                            # Read the images using their indices.
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

print ('Shape of Training Data', np.shape(training_data))
print ('Shape of Test Data', np.shape(test_data))

batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)

loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4 )

epochs = 20
train_losses = []
test_losses = []

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    train_loss = train(train_dataloader, model, loss_fn, optimizer)
    train_losses.append(train_loss)

    test_loss = test(test_dataloader, model, loss_fn)
    test_losses.append(test_loss)

print("Done!")

# Plot training and validation losses.
plt.figure(figsize=(10,5))
plt.title("Training and Validation Loss")
plt.plot(test_losses,label="validation")
plt.plot(train_losses,label="training")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Shape of Training Data (60000, 2)
# Shape of Test Data (10000, 2)
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=10, bias=True)
#   )
# )
# Epoch 1
# -------------------------------
# test loss:
# Accuracy: 81.2%, avg loss: 0.531981
#
# Epoch 2
# -------------------------------
# test loss:
# Accuracy: 83.5%, avg loss: 0.468125
#
# Epoch 3
# -------------------------------
# test loss:
# Accuracy: 84.5%, avg loss: 0.439176
#
# Epoch 4
# -------------------------------
# test loss:
# Accuracy: 85.2%, avg loss: 0.421177
#
# Epoch 5
# -------------------------------
# test loss:
# Accuracy: 85.5%, avg loss: 0.407892
#
# Epoch 6
# -------------------------------
# test loss:
# Accuracy: 86.0%, avg loss: 0.396920
#
# Epoch 7
# -------------------------------
# test loss:
# Accuracy: 86.3%, avg loss: 0.388390
#
# Epoch 8
# -------------------------------
# test loss:
# Accuracy: 86.4%, avg loss: 0.380757
#
# Epoch 9
# -------------------------------
# test loss:
# Accuracy: 86.7%, avg loss: 0.374382
#
# Epoch 10
# -------------------------------
# test loss:
# Accuracy: 86.8%, avg loss: 0.369244
#
# Epoch 11
# -------------------------------
# test loss:
# Accuracy: 87.0%, avg loss: 0.364269
#
# Epoch 12
# -------------------------------
# test loss:
# Accuracy: 87.1%, avg loss: 0.360308
#
# Epoch 13
# -------------------------------
# test loss:
# Accuracy: 87.3%, avg loss: 0.356549
#
# Epoch 14
# -------------------------------
# test loss:
# Accuracy: 87.4%, avg loss: 0.353369
#
# Epoch 15
# -------------------------------
# test loss:
# Accuracy: 87.6%, avg loss: 0.350275
#
# Epoch 16
# -------------------------------
# test loss:
# Accuracy: 87.6%, avg loss: 0.348275
#
# Epoch 17
# -------------------------------
# test loss:
# Accuracy: 87.6%, avg loss: 0.346089
#
# Epoch 18
# -------------------------------
# test loss:
# Accuracy: 87.6%, avg loss: 0.344396
#
# Epoch 19
# -------------------------------
# test loss:
# Accuracy: 87.7%, avg loss: 0.342637
#
# Epoch 20
# -------------------------------
# test loss:
# Accuracy: 87.9%, avg loss: 0.341582
#
# Done!

# %% [markdown]
# # Combination 6 has the highest accuracy and the lowest validation loss. Run the code cell of the combination 6 and then run the cell below to save the model and get the inference.

# %%
classes = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
   "Sneaker",
    "Bag",
  "Ankle boot",
]
#classes = np.array(test_data.class_to_idx.values())
#testimg = random.
model.eval()
sample_number = 300 # Keep 0 <= sample_number < 10,000
x, y = test_data[sample_number][0], test_data[sample_number][1]
model.to("cpu")
with torch.no_grad():
    pred = model(x)
    predicted, actual = classes[pred[0].argmax(0)], classes[y]
    print(f'Predicted: "{predicted}", Actual: "{actual}"')

img, label = test_data[sample_number]                            # Read the images using their indices.
    #figure.add_subplot(rows, cols, i)
plt.figure()
plt.title("Predcited: "+ predicted + "     Actual: " + labels_map[label])
plt.axis("off")
plt.imshow(img.squeeze(), cmap="gray")
# Out:
# Predicted: "Dress", Actual: "Dress"

# %% [markdown]
# #**Submission**
#
# ## **Submit a lab report containing codes, screenshots of output and tables for comparision of accuracies for both task 1 and task2 (for both MNIST and Fashion MNIST datasets) with your name and registration number at the top.**
#
# ## **Try to achieve the best accuracies you can in classifying the images.**
#
# ## **Remember, the more you elaborate your report, the higher the marks you will get.**
